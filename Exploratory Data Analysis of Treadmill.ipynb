# %% [markdown]
# # Exploratory Data Analysis

# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the dataset
df = pd.read_csv(r"C:/Users/Bismillah Traders/OneDrive/Desktop/Datasets/CardioGoodFitness.csv")
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
df.shape
# Out:
# (180, 9)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# ...

# %%
# removing duplicates value from dataset
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# ...

# %%
df.nunique()
# Out:
# Product           3
# Age              32
# Gender            2
# Education         8
# MaritalStatus     2
# Usage             6
# Fitness           5
# Income           62
# Miles            37
# dtype: int64

# %%
df['Product'].value_counts()
# Out:
# Product
# TM195    80
# TM498    60
# TM798    40
# Name: count, dtype: int64

# %% [markdown]
# # Data Visualization

# %%
sns.set_style('whitegrid')

# %%
sns.regplot(data = df, x = 'Age', y = 'Income')
plt.show()

# %%
# ploting the ratio among the product
sns.countplot(data = df, x = 'Product')
# Out:
# <Axes: xlabel='Product', ylabel='count'>

# %%
sns.histplot(data = df , x = 'Product', stat = 'percent')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Product', ylabel='Percent'>

# %%
sns.histplot(data = df, x = 'Product', hue = 'Gender', multiple='dodge' ,shrink=.8)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Product', ylabel='Count'>

# %%
sns.histplot(data = df , x = 'Gender', hue = 'Product', multiple = 'dodge' ,shrink =.8)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Gender', ylabel='Count'>

# %%
marital = df.MaritalStatus.value_counts()
gender = df.Gender.value_counts()

fig, axs = plt.subplots(1, 2)
axs[0].pie(data=gender, x=gender.values, labels=gender.index, radius=1.4, colors=['#f2bd1d', '#4B79BB'],autopct='%.2f')
axs[1].pie(data=marital, x=marital.values, labels=marital.index, radius=1.4,\
           autopct='%.2f', shadow=True, colors=['red', '#4B79BB'])
plt.show()

# %% [raw]
# sns.set_style('darkgrid')
# sns.histplot(data = df, x = 'Product' , hue = 'Usage' , multiple = 'dodge', palette ='RdBu' )

# %%
sns.histplot(data = df, x = 'Product', hue = 'Fitness', multiple = 'dodge' , palette = 'RdBu', shrink =.8)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Product', ylabel='Count'>

# %%
sns.histplot(data = df ,x='Product',hue='MaritalStatus',multiple='dodge',binwidth=2,shrink=.8)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Product', ylabel='Count'>

# %%
sns.stripplot(data = df , x = df.Education, y = df.Age, linewidth=.5)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plot = sns.countplot(data = df , x = 'Education')
plot.axes.set_title("Education Distribution", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Education Distribution')

# %% [markdown]
# #### converting the catagory from object to numerical for correlation

# %%
df_catagorical=df.select_dtypes(include=['object'])

from sklearn.preprocessing import LabelEncoder
for c in df_catagorical:
    
    le = LabelEncoder().fit(list(df[c].values))
    df[c] = le.transform(df[c].values)

# %%
df.dtypes
# Out:
# Product          int32
# Age              int64
# Gender           int32
# Education        int64
# MaritalStatus    int32
# Usage            int64
# Fitness          int64
# Income           int64
# Miles            int64
# dtype: object

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df, x="Fitness", y="Miles", hue="Usage", size="Usage")
# Out:
# <Axes: xlabel='Fitness', ylabel='Miles'>

# %% [markdown]
# # Conclusion
# From this CardiFitness Data we gain some valuable insights.
# #### Costomer Prference
# The most popular treadmill model is TM195, followed by TM498 and TM798
# #### Demographics & Usage
# Younger customers with higher fitness levels tend to use treadmills more frequently.
# #### Income & Product Choice
# Higher-income individuals are more likely to purchase premium treadmill models.
# #### Correlation Analysis
# A strong positive correlation exists between miles run and fitness level, reinforcing the impact of regular treadmill use.
